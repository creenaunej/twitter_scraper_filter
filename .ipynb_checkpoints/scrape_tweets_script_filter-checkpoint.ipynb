# %% [markdown]
# ## Twitter sentiment analysis
#
# - [NLTK documentation](https://www.nltk.org/howto/collocations.html)
# - [sentiment analysis tutorial](https://www.digitalocean.com/community/tutorials/how-to-perform-sentiment-analysis-in-python-3-using-the-natural-language-toolkit-nltk)
# - [Scrape tweets from twitter](https://towardsdatascience.com/how-to-scrape-tweets-from-twitter-59287e20f0f1)

# %% [markdown]
# This script performs the folling functions
#
# - Import necessary libraries
# - Script1 - Scrape tweets from homepage
# - Script 2 - Class method - Scrape tweets from a particular user - **need screen_name** include retweets
# - Script 3 - Class method - Scrape tweets from a particular user - **need screen_name** Exclude retweets
# - Script 4 - Search tweets with keyword and date
# - Script 5 - Profanity filter
# - Script 6-  Profanity Censor - Script will censor words but leave tweets intact
# - Script 7 -  Censor tweets in the dataframe

# %%
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords') #Dont need this unless stopwords need to be updated
import string
#This package will allow us to remove punctuation
from nltk.tokenize import RegexpTokenizer
#import regex
#import twitter scraper 
import tweepy
#Import Json to allow us to get an organize the info from twitter
import json
#Import datetime to use in our dataframe 
import datetime
#import pandas to create and manipulate dataframes 
import pandas as pd
#import profanity checker 
from profanity_check import predict, predict_prob
#Import profanity Filter 
from profanity_filter import ProfanityFilter

# %% [markdown]
# #### Twitter API keys
# - consumer_key = "KasxVpXExYm4hVdMo0ptDcEhb"
# - consumer_secret = "V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr"
# - access_token = "152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU"
# - access_token_secret = "83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA"

# %% [markdown]
# ### Script 1 -  Scrape tweets from homepage

# %%
#This script will print tweets from my homepage - it is unstructured

#Add your credentials here
twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }

#Setup access to API
auth = tweepy.OAuthHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])

api = tweepy.API(auth)

#Make call on home timeline, print each tweets text
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Ekkkk!!  Just submitted a grant application, wish me luck!!
# Inside the war on fake consumer reviews https://t.co/udG0sYQ9Ck
# Why 'more mature' Nick Kyrgios says he's ready for Wimbledon glory https://t.co/btOz9VAzT5
# Putin says Russia barely started in Ukraine, dares West on battlefield https://t.co/wInIZ0NDSn
# Tempting people to eat more Asian carp could boost biodiversity in rivers across America’s South and Midwest. With… https://t.co/UotjjBum2R
# Oil dips as investors torn by tight supply worries and recession fears https://t.co/DeaZJLo9Mg https://t.co/iGnDriKR9P
# Ni Kuang, a prolific author of fantasy novels imbued with criticism of the Chinese Communist Party and a screenwrit… https://t.co/kwZfFORbjF
# A Swiss startup is offering underground bunkers for the mega-rich. The company says the bunker can make its own wat… https://t.co/0rNAT1Bx55
# SICINIUS. Peace!
# Berkshire Hathaway owns 18.7% of Occidental after new 12 mln share purchase https://t.co/6KXn5XzLLC https://t.co/upnWLHV5aO
# Abortion law is decided in Australia at the state and territory level. But why do we lack federal abortion legislat… https://t.co/uDlQMo9POv
# British navy says it seized smuggled Iranian missiles https://t.co/MTuOFj17p6 https://t.co/6WE5NdiqCZ
# Gymnastics pioneer Simone Biles and two-time World Cup winner Megan Rapinoe were among 17 honorees to receive the P… https://t.co/GMqfiZYhK3
# PLEBEIANS. To th' rock, to th' rock, with him!
# U.K. Prime Minister Boris Johnson has agreed to resign.
#
# He gave in after more than 40 ministers quit his governmen… https://t.co/ovzakp9rSv
# Governments spent $20.5b on first home buyer help that pushes up prices: report | @TawarRazaghi https://t.co/Da7gtcwAWh
# ‘Leave means leave’: what the papers said about Boris Johnson’s sort-of resignation https://t.co/t3TxUS8VTv
# Lawsuit accuses troubled crypto lender Celsius Network of fraud https://t.co/cxbWZC6ZuM https://t.co/HQqsmdYkHx
# Natalie Portman talks about her role in Marvel’s superhero movie ‘Thor: Love and Thunder’ https://t.co/p6K20Xjj6n https://t.co/4vA1jrjjJD
# From the Wholesome Softboi to the ‘Radiohead? More Like Radi-BRO-head’-boi, meet the four types of softbois you'll… https://t.co/KKZdrL0tkZ

# %%
# Print all of the metadata from the above tweets
public_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd99936bdf0>, _json={'created_at': 'Fri Jul 08 02:34:02 +0000 2022', 'id': 1545234728391176192, 'id_str': '1545234728391176192', 'text': 'Ekkkk!!  Just submitted a grant application, wish me luck!!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 49598833, 'id_str': '49598833', 'name': 'MGH', 'screen_name': 'MichelleGHunder', 'location': 'Melbourne', 'description': 'Michelle Grace Hunder | Photographer | #HERSOUNDHERSTORY | Supported @Nikon_Australia  | Twitch Partnered Streamer | MGH Masterclass | Podcast | 📷 for @oneruel', 'url': 'https://t.co/1IEZA4dmjj', 'entities': {'url': {'urls': [{'url': 'https://t.co/1IEZA4dmjj', 'expanded_url': 'https://linktr.ee/michelleghunder', 'display_url': 'linktr.ee/michelleghunder', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 11995, 'friends_count': 2639, 'listed_count': 103, 'created_at': 'Mon Jun 22 11:09:40 +0000 2009', 'favourites_count': 128183, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 27878, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'ABB8C2', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1529403668713582592/urxQ4cLC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1529403668713582592/urxQ4cLC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49598833/1617622766', 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '910A18', 'profile_text_color': '111212', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 7, 8, 2, 34, 2, tzinfo=datetime.timezone.utc), id=1545234728391176192, id_str='1545234728391176192', text='Ekkkk!!  Just submitted a grant application, wish me luck!!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fd99936bdf0>, _json={'id': 49598833, 'id_str': '49598833', 'name': 'MGH', 'screen_name': 'MichelleGHunder', 'location': 'Melbourne', 'description': 'Michelle Grace Hunder | Photographer | #HERSOUNDHERSTORY | Supported @Nikon_Australia  | Twitch Partnered Streamer | MGH Masterclass | Podcast | 📷 for @oneruel', 'url': 'https://t.co/1IEZA4dmjj', 'entities': {'url': {'urls': [{'url': 'https://t.co/1IEZA4dmjj', 'expanded_url': 'https://linktr.ee/michelleghunder', 'display_url': 'linktr.ee/michelleghunder', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 11995, 'friends_count': 2639, 'listed_count': 103, 'created_at': 'Mon Jun 22 11:09:40 +0000 2009', 'favourites_count': 128183, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'sta ...

# %%
# Organize metadata info to determine what to use 
status = public_tweets[0]

#convert to string
json_str = json.dumps(status._json)

#deserialise string into python object
parsed = json.loads(json_str)

print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Jul 08 02:34:02 +0000 2022",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1545234728391176192,
#     "id_str": "1545234728391176192",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "text": "Ekkkk!!  Just submitted a grant application, wish me luck!!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Mon Jun 22 11:09:40 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Michelle Grace Hunder | Photographer | #HERSOUNDHERSTORY | Supported @Nikon_Australia  | Twitch Partnered Streamer | MGH Masterclass | Podcast | \ud83d\udcf7 for @oneruel",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "linktr.ee/michelleghunder",
#                         "expanded_url": "https://linktr.ee/michelleghunder",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/1IEZA4dmjj"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 128183,
#         "follow_request_sent": false,
#         "followers_count": 11995,
#         "following": true,
#         "friends_count": 2639,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 49598833,
#         "id_str": "49598833",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 103,
#         "location": "Melbourne",
#         "name": "MGH",
#         "notifications": false,
#         "profile_background_color": "ABB8C2",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/49598833/1617622766",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1529403668713582592/urxQ4cLC_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1529403668713582592/urxQ4cLC_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "910A18",
#         "profile_text_color": "111212",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "MichelleGHunder",
#         "statuses_count": 27878,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/1IEZA4dmjj",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %% [markdown]
# ### Script 2 - Class method
# ##### Scrape tweets from a particular user - **need screen_name** include retweets

# %%
#include retweets

class TweetMiner(object):

    result_limit    =   20    
    data            =   []
    api             =   False
    
    twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }
    
    
    def __init__(self, keys_dict=twitter_keys, api=api, result_limit = 20):
        
        self.twitter_keys = keys_dict
        
        auth = tweepy.OAuthHandler(keys_dict['consumer_key'], keys_dict['consumer_secret'])
        auth.set_access_token(keys_dict['access_token_key'], keys_dict['access_token_secret'])
        
        self.api = tweepy.API(auth)
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="AOC", #Alexandra Ocasio Cortez 
                         mine_rewteets=False,
                         max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            if last_tweet_id:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                     count=self.result_limit,
                                                     max_id=last_tweet_id - 1,
                                                     tweet_mode = 'extended',
                                                     include_retweets=True
                                                    )        
            else:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                        count=self.result_limit,
                                                        tweet_mode = 'extended',
                                                        include_retweets=True)
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'name':            item.user.name,
                    'screen_name':     item.user.screen_name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.full_text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                    'favourite_count': item.favorite_count,
                    'hashtags':        item.entities['hashtags'],
                    'status_count':    item.user.statuses_count,
                    'location':        item.place,
                    'source_device':   item.source
                }
                
                try:
                    mined['retweet_text'] = item.retweeted_status.full_text
                except:
                    mined['retweet_text'] = 'None'
                try:
                    mined['quote_text'] = item.quoted_status.full_text
                    mined['quote_screen_name'] = status.quoted_status.user.screen_name
                except:
                    mined['quote_text'] = 'None'
                    mined['quote_screen_name'] = 'None'
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %% [markdown]
# ### Script 3 - Class method
# ##### Scrape tweets from a particular user - **need screen_name** Exclude retweets

# %%
#Remove RETWEETS 
class TweetMiner(object):

    result_limit    =   20    
    data            =   []
    api             =   False
    
    twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }
    
    
    def __init__(self, keys_dict=twitter_keys, api=api, result_limit = 20):
        
        self.twitter_keys = keys_dict
        
        auth = tweepy.OAuthHandler(keys_dict['consumer_key'], keys_dict['consumer_secret'])
        auth.set_access_token(keys_dict['access_token_key'], keys_dict['access_token_secret'])
        
        self.api = tweepy.API(auth)
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="MMFlint", #Michael Moore 
                         mine_rewteets=False,
                         max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            if last_tweet_id:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                     count=self.result_limit,
                                                     max_id=last_tweet_id - 1,
                                                     tweet_mode = 'extended'
                                                    )        
            else:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                        count=self.result_limit,
                                                        tweet_mode = 'extended')
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'name':            item.user.name,
                    'screen_name':     item.user.screen_name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.full_text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                    'favourite_count': item.favorite_count,
                    'hashtags':        item.entities['hashtags'],
                    'status_count':    item.user.statuses_count,
                    'location':        item.place,
                    'source_device':   item.source
                }
                
                try:
                    mined['retweet_text'] = item.retweeted_status.full_text
                except:
                    mined['retweet_text'] = 'None'
                try:
                    mined['quote_text'] = item.quoted_status.full_text
                    mined['quote_screen_name'] = status.quoted_status.user.screen_name
                except:
                    mined['quote_text'] = 'None'
                    mined['quote_screen_name'] = 'None'
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %%
miner=TweetMiner(result_limit = 20 )

# %%
#Print Mined tweets as a dataframe
mined_tweets = miner.mine_user_tweets(user='MMFlint', max_pages=17)

mined_tweets_df= pd.DataFrame(mined_tweets)

# %%
#Print the 7th row to see if script is accurate 
mined_tweets_df.loc[[6]]
# Out:
#               tweet_id           name screen_name  retweet_count  \
# 6  1542208128154058758  Michael Moore     MMFlint           3624
#
#                                                 text  \
# 6  RT @RonFilipkowski: Not edited or photoshopped...
#
#                     mined_at                created_at  favourite_count  \
# 6 2022-07-07 22:35:17.857227 2022-06-29 18:07:25+00:00                0
#
#   hashtags  status_count location       source_device  \
# 6       []         16008     None  Twitter for iPhone
#
#                                         retweet_text quote_text  \
# 6  Not edited or photoshopped. https://t.co/dxSnR...       None
#
#   quote_screen_name
# 6              None

# %% [markdown]
# ### Script 4 - Search tweets with keyword and date
# https://datascienceparichay.com/article/get-data-from-twitter-api-in-python-step-by-step-guide/

# %%
#Key word search Query is not case sensitive 

search_query = "biden -filter:retweets"

# %%
# get tweets from the API
tweets = tweepy.Cursor(api.search_tweets,
              q=search_query,
              lang="en",
              since="2022-06-28").items(100)
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Total Tweets fetched: 100

# %%
#Print scraped tweets to a dataframe 
# intialize the dataframe
tweets_df = pd.DataFrame()
# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
                                               'screen_name' : tweet.user.screen_name,
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)
# show the dataframe
tweets_df.head()
# Out:
#           user_name      screen_name              user_location  \
# 0  garfield dingess  DingessGarfield
# 1               Rod       dudewtfnow  Newport Beach, California
# 2        Ronnie 101      rondonzo101                 Tucson, AZ
# 3       Diane Hayes     lemontarting                 Austin, TX
# 4       Air in Gear        eringhere                  Minnesota
#
#                                     user_description  user_verified  \
# 0                                                             False
# 1  🏄 NBA and SkateBoarding 🤙.                    ...          False
# 2                                  Keep America free          False
# 3  Former atty current mom Voting rights matter. ...          False
# 4  Pro-abortion. Pro-LGBTQIA+ rights. Working to ...          False
#
#                        date  \
# 0 2022-07-08 02:35:27+00:00
# 1 2022-07-08 02:35:26+00:00
# 2 2022-07-08 02:35:26+00:00
# 3 2022-07-08 02:35:26+00:00
# 4 2022-07-08 02:35:26+00:00
#
#                                                 text hashtags  \
# 0  @CalltoActivism They already do.  Biden forget...     None
# 1  Tucker Carlson reverses position on immigratio...     None
# 2  Isn't it amazing that hunter Biden can't speak...     None
# 3  @DeanObeidallah Remember when Hunter Biden got...     None
# 4  Michigan is ripe for support. MI-03 has a GOP ...     None
#
#                 source
# 0      Twitter Web App
# 1   Twitter for iPhone
# 2  Twitter for Android
# 3   Twitter for iPhone
# 4      Twitter Web App

# %% [markdown]
# ### Script 5 - Profanity filter

# %%
#This function adds a new column into the dataframe above and uses a boolean value to let you know if it contains profanities    

def detect_profanity(df): 
    df['contains_profanity'] = predict(df['text'])
    return df

# %%
# Run the above function through the dataframe
tweets_df_prof= detect_profanity(tweets_df)
tweets_df_prof
# Out:
#                           user_name      screen_name  \
# 0                  garfield dingess  DingessGarfield
# 1                               Rod       dudewtfnow
# 2                        Ronnie 101      rondonzo101
# 3                       Diane Hayes     lemontarting
# 4                       Air in Gear        eringhere
# ..                              ...              ...
# 95                   Jennifer Girod    JenniferGirod
# 96  MyFirstSocialMediaAccount 🇨🇦 🇺🇦  MyFirstSocialM2
# 97                 Angela Stadalsky           8NO4RE
# 98                    Bas Klootwijk    BasKlootwijk1
# 99                         Wolfbane     WolfbaneMoon
#
#                 user_location  \
# 0
# 1   Newport Beach, California
# 2                  Tucson, AZ
# 3                  Austin, TX
# 4                   Minnesota
# ..                        ...
# 95
# 96
# 97
# 98                Salty Spray
# 99                 U.S.A.  🇺🇸
#
#                                      user_description  user_verified  \
# 0                                                              False
# 1   🏄 NBA and SkateBoarding 🤙.                    ...          False
# 2                                   Keep America free          False
# 3   Former atty current mom Voting rights matter. ...          False
# 4   Pro-abortion. Pro-LGBTQIA+ rights. Working to ...          False
# ..                                                ...            ...
# 95                                                             False
# 96                                                             False
# 97           Wife,mother, patriot, proud Conservative          False
# 98  Ik ben geïnteresseerd in troep en trollen.\nIk...          False
# 99  I ate with the rich & was admired. I ate with ...          False
#
#                         date  \
# 0  2022-07-08 02:35:27+00:00
# 1  2022-07-08 02:35:26+00:00
# 2  2022-07-08 02:35:26+00:00
# 3  2022-07-08 02:35:26+00:00
# 4  2022-07-08 02:35:26+00:00
# ..                       ...
# 95 2022-07-08 02:34:27+00:00
# 96 2022-07-08 02:34:27+00:00
# 97 2022-07-08 02:34:27+00:00
# 98 2022-07-08 02:34:27+00:00
# 99 2022-07-08 02:34:27+00:00
#
#                                                  text  \
# 0   @CalltoActivism They already do.  Biden forget...
# 1   Tucker Carlson reverses position on immigratio...
# 2   Isn't it amazing that hunter Biden can't speak...
# 3   @DeanObeidallah Remember when Hunter Biden got...
# 4   Michigan is ripe for support. MI-03 has a GOP ...
# ..                                                ...
# 95  @Barbara35980709 @bluebear5922 @RepMTG @GOPLea...
# 96  @CarolynGarman5 @MacFarlaneNews He agrees Bide...
# 97  If Biden and the Democrats\n  Think that they ...
# 98  Timcast IRL - #DutchCops FIRE ON #DutchFarmers...
# 99  @Leerose1985 @CAPatriot73 The economy shrunk f...
#
#                                    hashtags               source  \
# 0                                      None      Twitter Web App
# 1                                      None   Twitter for iPhone
# 2                                      None  Twitter for Android
# 3                                      None   Twitter for iPhone
# 4                                      None      Twitter Web App
# ..                                      ...                  ...
# 95                                     None  Twitter for Android
# 96                                     None      Twitter Web App
# 97                                     None  Twitter for Android
# 98  [DutchCops, DutchFarmers, GlobalAgenda]      Twitter Web App
# 99                                     None      Twitter Web App
#
#     contains_profanity
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 95                   0
# 96                   0
# 97                   0
# 98                   0
# 99                   0
#
# [100 rows x 10 columns]

# %%
#Print only profanity tweets to see if this script works 
profanity_tweet = tweets_df_prof[tweets_df_prof['contains_profanity'] == 1]
profanity_tweet
# Out:
#            user_name      screen_name user_location  \
# 8           Gregoryr            Dos54            Ca
# 35     Mark Bedinger     MarkBedinger
# 42             Edith       Edith83120
# 47  Duckfootball1991  Duckfootball192
#
#                        user_description  user_verified  \
# 8   Retired worked in the auto industry          False
# 35                                               False
# 42                                               False
# 47                                    .          False
#
#                         date  \
# 8  2022-07-08 02:35:22+00:00
# 35 2022-07-08 02:35:09+00:00
# 42 2022-07-08 02:35:07+00:00
# 47 2022-07-08 02:35:03+00:00
#
#                                                  text hashtags  \
# 8   Joe Biden should be put in jail for destroying...     None
# 35  @David_Charts @BidensWins Awww Biden ain’t got...     None
# 42  @RyanShead Hunter Biden is trending because hi...     None
# 47  @EricOwnby1 @BryanRo89512832 @ClayTravis @NPR ...     None
#
#                  source  contains_profanity
# 8       Twitter Web App                   1
# 35   Twitter for iPhone                   1
# 42  Twitter for Android                   1
# 47     Twitter for iPad                   1

# %% [markdown]
# ### Script 6-  Profanity Censor
#
# ##### Script will censor words but leave tweets intact
#
# https://lubna2004.medium.com/profanity-to-be-or-not-to-be-dd32d53648f7

# %%
#Test1
predict(['CRAP! What a stupid decision!'])

#Crap and Stupid are examples of profanities 
#This is delineated by the boolean value of one
# Out:
# array([1])

# %%
#Test2
predict(['Lovely Spring Weather!'])
#There are no profanities contained in this
# Out:
# array([0])

# %%
#Test 3 
#Use profanity Filter - to change and censor profane words

# %%
#Initialize profanity filter and what characters will replace profane language
pf = ProfanityFilter()
pf.censor_char = '@'
pf.censor("Crap! What a stupid decision")
# Out:
# '@@@@! What a stupid decision'

# %%
#Copy variable
censor_profanity_tweet = profanity_tweet

# %%
#Check datatypes - profanity filter can only be run on strings
profanity_tweet['text'].dtypes
# Out:
# dtype('O')

# %%
profanity_tweet.dtypes
# Out:
# user_name                          object
# screen_name                        object
# user_location                      object
# user_description                   object
# user_verified                        bool
# date                  datetime64[ns, UTC]
# text                               object
# hashtags                           object
# source                             object
# contains_profanity                  int64
# dtype: object

# %%
#Convert text column to string
string = profanity_tweet.astype({'text':'string'})

# %%
string['text']
# Out:
# 8     Joe Biden should be put in jail for destroying...
# 35    @David_Charts @BidensWins Awww Biden ain’t got...
# 42    @RyanShead Hunter Biden is trending because hi...
# 47    @EricOwnby1 @BryanRo89512832 @ClayTravis @NPR ...
# Name: text, dtype: string

# %%
#Check that 'Text' column has been converted to string
string.dtypes
# Out:
# user_name                          object
# screen_name                        object
# user_location                      object
# user_description                   object
# user_verified                        bool
# date                  datetime64[ns, UTC]
# text                               string
# hashtags                           object
# source                             object
# contains_profanity                  int64
# dtype: object

# %%
#Copy variable 
string2 = string[["text"]]
string2.dtypes
# Out:
# text    string
# dtype: object

# %%
#This will allow us to print the entire string for the next cell
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-27-2c1c50702082>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
mystring3 = repr(string2)
#Check that profanity censor works 
pf.censor(mystring3)
# Out:
# "                                                                                                                                                                                                                                                              text\n8   Joe Biden should be put in jail for destroying the USA. Can't afford the gas to go to my son's wedding                                                                                                                                                        \n35  @David_Charts @BidensWins Awww Biden ain’t got @@@@ on the Big Dipper. @@@ wipes                                                                                                                                                                              \n42  @RyanShead Hunter Biden is trending because his old man sold man sold barrels of oil to China today from our strategic reserve. Who cares about Trump - the former president - and the former 1st family. We're thinking today. Pull your head out of your @@@\n47  @EricOwnby1 @BryanRo89512832 @ClayTravis @NPR Everyone knew what was coming and Biden was threatening them with sanctions if they invaded. I was shocked she would even go there with the existing climate. Dumb dumb move by her and her advisors.           "

# %%
#Compare censored version above to original dataframe
display(mystring3)
# Out:
# "                                                                                                                                                                                                                                                              text\n8   Joe Biden should be put in jail for destroying the USA. Can't afford the gas to go to my son's wedding                                                                                                                                                        \n35  @David_Charts @BidensWins Awww Biden ain’t got shit on the Big Dipper. Ass wipes                                                                                                                                                                              \n42  @RyanShead Hunter Biden is trending because his old man sold man sold barrels of oil to China today from our strategic reserve. Who cares about Trump - the former president - and the former 1st family. We're thinking today. Pull your head out of your ass\n47  @EricOwnby1 @BryanRo89512832 @ClayTravis @NPR Everyone knew what was coming and Biden was threatening them with sanctions if they invaded. I was shocked she would even go there with the existing climate. Dumb dumb move by her and her advisors.           "

# %%
string3 = string

# %%
#Initialize censor function to run through the 'text' column - check that function works on tweets containing profanities
def censortweet(x):
   return pf.censor(x)
string3["text"] = string3["text"].apply(censortweet)

# %%
string3
# Out:
#            user_name      screen_name user_location  \
# 8   Gregoryr          Dos54            Ca
# 35  Mark Bedinger     MarkBedinger
# 42  Edith             Edith83120
# 47  Duckfootball1991  Duckfootball192
#
#                        user_description  user_verified  \
# 8   Retired worked in the auto industry  False
# 35                                       False
# 42                                       False
# 47  .                                    False
#
#                         date  \
# 8  2022-07-08 02:35:22+00:00
# 35 2022-07-08 02:35:09+00:00
# 42 2022-07-08 02:35:07+00:00
# 47 2022-07-08 02:35:03+00:00
#
#                                                                                                                                                                                                                                                               text  \
# 8   Joe Biden should be put in jail for destroying the USA. Can't afford the gas to go to my son's wedding
# 35  @David_Charts @BidensWins Awww Biden ain’t got @@@@ on the Big Dipper. @@@ wipes
# 42  @RyanShead Hunter Biden is trending because his old man sold man sold barrels of oil to China today from our strategic reserve. Who cares about Trump - the former president - and the former 1st family. We're thinking today. Pull your head out of your @@@
# 47  @EricOwnby1 @BryanRo89512832 @ClayTravis @NPR Everyone knew what was coming and Biden was threatening them with sanctions if they invaded. I was shocked she would even go there with the existing climate. Dumb dumb move by her and her advisors.
#
#    hashtags               source  contains_profanity
# 8   None     Twitter Web App      1
# 35  None     Twitter for iPhone   1
# 42  None     Twitter for Android  1
# 47  None     Twitter for iPad     1

# %% [markdown]
# ## Script 7 -  Censor tweets in the dataframe

# %%
# Copy the original 
tweets_df_censor = tweets_df

# %%
# Text column to string will allow us to censor 
tweets_df_censor = tweets_df_censor.astype({'text':'string'})
tweets_df_censor.head()
# Out:
#           user_name      screen_name              user_location  \
# 0  garfield dingess  DingessGarfield
# 1  Rod               dudewtfnow       Newport Beach, California
# 2  Ronnie 101        rondonzo101      Tucson, AZ
# 3  Diane Hayes       lemontarting     Austin, TX
# 4  Air in Gear       eringhere        Minnesota
#
#                                                                                                                                                    user_description  \
# 0
# 1  🏄 NBA and SkateBoarding 🤙.                           Some Parody Tweets!
# 2  Keep America free
# 3  Former atty current mom Voting rights matter. BLM. Democracy is on life support.
# 4  Pro-abortion. Pro-LGBTQIA+ rights. Working to be anti-racist every day. VOTE. VOTE. VOTE. Vote like you're saving democracy; vote like you're saving our rights.
#
#    user_verified                      date  \
# 0  False         2022-07-08 02:35:27+00:00
# 1  False         2022-07-08 02:35:26+00:00
# 2  False         2022-07-08 02:35:26+00:00
# 3  False         2022-07-08 02:35:26+00:00
# 4  False         2022-07-08 02:35:26+00:00
#
#                                                                                                                                                                                                                                    text  \
# 0  @CalltoActivism They already do.  Biden forget to tell Americans that.  We are paying that stimulus money back right now through inflation.  Vote red!
# 1  Tucker Carlson reverses position on immigration after interviewing Hot Blonde Dutch Reporter. He is urging Biden to reopen our borders 🤣
#  https://t.co/BxQm6MwcIE
# 2  Isn't it amazing that hunter Biden can't speak Ukraine Chinese or Russian In all these countries that he owns And has partnership Not to mention any experience or Knowledge of those company
# 3  @DeanObeidallah Remember when Hunter Biden got $2B from the Saudis after helping them murder Jamal Khashoggi? Oh right, that was Trump’s son in law who worked in the White House.
# 4  Michigan is ripe for support. MI-03 has a GOP incumbent but was redistricted into a Biden +9 district. Currently a toss up, with recent polls leaning slightly toward the Dems. Big pick up opportunity to offset other losses. 12/?
#
#   hashtags               source  contains_profanity
# 0  None     Twitter Web App      0
# 1  None     Twitter for iPhone   0
# 2  None     Twitter for Android  0
# 3  None     Twitter for iPhone   0
# 4  None     Twitter Web App      0

# %%
#Run dataframe through censortweet function from above 
tweets_df_censor["text"] = tweets_df_censor["text"].apply(censortweet)

# %%
#Check that function worked - row 14 has the profanities censored using the functions
tweets_df_censor.loc[[8]]
# Out:
#   user_name screen_name user_location                     user_description  \
# 8  Gregoryr  Dos54       Ca            Retired worked in the auto industry
#
#    user_verified                      date  \
# 8  False         2022-07-08 02:35:22+00:00
#
#                                                                                                      text  \
# 8  Joe Biden should be put in jail for destroying the USA. Can't afford the gas to go to my son's wedding
#
#   hashtags           source  contains_profanity
# 8  None     Twitter Web App  1
