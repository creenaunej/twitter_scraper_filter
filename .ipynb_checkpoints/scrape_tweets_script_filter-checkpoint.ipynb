# %% [markdown]
# ## Twitter sentiment analysis
#
# - [NLTK documentation](https://www.nltk.org/howto/collocations.html)
# - [sentiment analysis tutorial](https://www.digitalocean.com/community/tutorials/how-to-perform-sentiment-analysis-in-python-3-using-the-natural-language-toolkit-nltk)
# - [Scrape tweets from twitter](https://towardsdatascience.com/how-to-scrape-tweets-from-twitter-59287e20f0f1)

# %% [markdown]
# This script performs the folling functions
#
# - Import necessary libraries
# - Script to scrape tweets from an account with retweets
# - Script to scrape tweets from an account without retweets
# - Script to scrape tweets from all accounts based on keyword
# - Run data frame through a script that creates a new column with a boolean value if it contains profanity
# - Run the dataframe through a profanity filter to remove any profanities
# - Run script to censor dataframes for profanity

# %%
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords') #Dont need this unless stopwords need to be updated
import string
#This package will allow us to remove punctuation
from nltk.tokenize import RegexpTokenizer
#import regex
#import twitter scraper 
import tweepy
#Import Json to allow us to get an organize the info from twitter
import json
#Import datetime to use in our dataframe 
import datetime
#import pandas to create and manipulate dataframes 
import pandas as pd
#import joblib
from profanity_check import predict, predict_prob
#Import profanity Filter 
from profanity_filter import ProfanityFilter

# %% [markdown]
# #### Twitter API keys
# - consumer_key = "KasxVpXExYm4hVdMo0ptDcEhb"
# - consumer_secret = "V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr"
# - access_token = "152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU"
# - access_token_secret = "83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA"

# %%
#This script will print tweets from my homepage - it is unstructured

#Add your credentials here
twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }

#Setup access to API
auth = tweepy.OAuthHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])

api = tweepy.API(auth)

#Make call on home timeline, print each tweets text
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Fed's fear of entrenched high inflation fueled big rate hike, minutes show https://t.co/8wClt5cOFZ https://t.co/Hr0z5Bjwc5
# With fast-growing cities comes increasing food waste. San Francisco has found a solution to the problem https://t.co/b1aUsQsBL5
# Opinion: Perrottet risks a train wreck in battle with union | Alexandra Smith
# https://t.co/y7MCK01AVf
# Twitter has been in a face-off with the Indian government over the censoring of critical tweets by journalists, act… https://t.co/2pP3fwTN5w
# Kate Bedingfield, the White House communications director, will step down from her position this summer, White Hous… https://t.co/5NBN6mHTia
# The European Parliament has backed EU rules to allow investors to label and market investments in gas and nuclear '… https://t.co/m7gFO64EnB
# As WNBA star Brittney Griner remains detained in Russia on drug charges, U.S. President Joe Biden tried to assure h… https://t.co/m8gAxLgyZx
# CORIOLANUS. Must I go show them my unbarb'd sconce? Must I
# RT @USConst_Amend_I: @JaredLPatterson @RepMaryGonzalez Don’t skip the best part, either!
#
# https://t.co/MwOgaI1N0N
# Injured Nadal unsure if he can play semis against Kyrgios https://t.co/ZH8YR7mheM https://t.co/HJiIbFY8Vk
# RT @projectpayphone: A couple more "last payphones of New York" from Sunday. UWS. Reports of at least one more in BK and another in Auburnd…
# RT @MyNews13: 🎧: “DeSantis is a very small man, a very bitter person…A lot of people don't like DeSantis because a lot of people don't like…
# RT @professornaite: We officially launched our 2022 Data Science and Critical Mathematics (#DSCM22) Workshop this evening with family orien…
# HSBC in talks to sell Russian lending business to Expobank -source https://t.co/KNESwBEyQN https://t.co/2QOTglvEg0
# RT @Abihabib: “I live in a country where the president was killed. If something like this can happen to a president with all that security,…
# Ons Jabeur is bidding to become the first woman from Africa to win a major as she reaches her maiden Grand Slam sem… https://t.co/9JO5VNLTYZ
# Prithee now, say you will, and go about it.
# 2nd this https://t.co/pznVJXzACa
# Here is a video of her planting it: https://t.co/HQUF3M1bKH
# Here is @OMarkarova planting sunflowers a couple of months ago: https://t.co/HQUF3M1bKH

# %%
#This will print all of the metadata from the above tweets
public_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7f8d8b6657f0>, _json={'created_at': 'Thu Jul 07 01:00:39 +0000 2022', 'id': 1544848838120415232, 'id_str': '1544848838120415232', 'text': "Fed's fear of entrenched high inflation fueled big rate hike, minutes show https://t.co/8wClt5cOFZ https://t.co/Hr0z5Bjwc5", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8wClt5cOFZ', 'expanded_url': 'http://reut.rs/3uSduDt', 'display_url': 'reut.rs/3uSduDt', 'indices': [75, 98]}], 'media': [{'id': 1544848836304191495, 'id_str': '1544848836304191495', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg', 'url': 'https://t.co/Hr0z5Bjwc5', 'display_url': 'pic.twitter.com/Hr0z5Bjwc5', 'expanded_url': 'https://twitter.com/Reuters/status/1544848838120415232/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1544848836304191495, 'id_str': '1544848836304191495', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg', 'url': 'https://t.co/Hr0z5Bjwc5', 'display_url': 'pic.twitter.com/Hr0z5Bjwc5', 'expanded_url': 'https://twitter.com/Reuters/status/1544848838120415232/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}}}]}, 'source': '<a href="https://trueanthem.com/" rel="nofollow">True Anthem</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1652541, 'id_str': '1652541', 'name': 'Reuters', 'screen_name': 'Reuters', 'location': 'Around the world', 'description': 'Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.', 'url': 'http://t.co/BmHxhkm3Mh', 'entities': {'url': {'urls': [{'url': 'http://t.co/BmHxhkm3Mh', 'expanded_url': 'http://www.reuters.com', 'display_url': 'reuters.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 25356527, 'friends_count': 1227, 'listed_count': 134761, 'created_at': 'Tue Mar 20 17:46:05 +0000 2007', 'favourites_count': 753, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 878889, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '444444', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1652541/1573687397', 'profile_link_color': '006F97', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'F5F5F5', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_se ...

# %%
status = public_tweets[0]

#convert to string
json_str = json.dumps(status._json)

#deserialise string into python object
parsed = json.loads(json_str)

print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Jul 07 01:00:39 +0000 2022",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/Hr0z5Bjwc5",
#                 "expanded_url": "https://twitter.com/Reuters/status/1544848838120415232/photo/1",
#                 "id": 1544848836304191495,
#                 "id_str": "1544848836304191495",
#                 "indices": [
#                     99,
#                     122
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "medium": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 356,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/Hr0z5Bjwc5"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "reut.rs/3uSduDt",
#                 "expanded_url": "http://reut.rs/3uSduDt",
#                 "indices": [
#                     75,
#                     98
#                 ],
#                 "url": "https://t.co/8wClt5cOFZ"
#             }
#         ],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/Hr0z5Bjwc5",
#                 "expanded_url": "https://twitter.com/Reuters/status/1544848838120415232/photo/1",
#                 "id": 1544848836304191495,
#                 "id_str": "1544848836304191495",
#                 "indices": [
#                     99,
#                     122
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FXBn1OeWQAcIJwp.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "medium": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 356,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/Hr0z5Bjwc5"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1544848838120415232,
#     "id_str": "1544848838120415232",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://trueanthem.com/\" rel=\"nofollow\">True Anthem</a>",
#     "text": "Fed's fear of entrenched high inflation fueled big rate hike, minutes show https://t.co/8wClt5cOFZ https://t.co/Hr0z5Bjwc5",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Mar 20 17:46:05 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "reuters.com",
#                         "expanded_url": "http://www.reuters.com",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/BmHxhkm3Mh"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 753,
#         "follow_request_sent": false,
#         "followers_count": 25356527,
#         "following": true,
#         "friends_count": 1227,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1652541,
#         "id_str": "1652541",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 134761,
#         "location": "Around the world",
#         "name": "Reuters",
#         "notifications": false,
#         "profile_background_color": "444444",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1652541/1573687397",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_link_color": "006F97",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "F5F5F5",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Reuters",
#         "statuses_count": 878889,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "http://t.co/BmHxhkm3Mh",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %%
#include retweets

class TweetMiner(object):

    result_limit    =   20    
    data            =   []
    api             =   False
    
    twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }
    
    
    def __init__(self, keys_dict=twitter_keys, api=api, result_limit = 20):
        
        self.twitter_keys = keys_dict
        
        auth = tweepy.OAuthHandler(keys_dict['consumer_key'], keys_dict['consumer_secret'])
        auth.set_access_token(keys_dict['access_token_key'], keys_dict['access_token_secret'])
        
        self.api = tweepy.API(auth)
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="AOC", #Alexandra Ocasio Cortez 
                         mine_rewteets=False,
                         max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            if last_tweet_id:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                     count=self.result_limit,
                                                     max_id=last_tweet_id - 1,
                                                     tweet_mode = 'extended',
                                                     include_retweets=True
                                                    )        
            else:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                        count=self.result_limit,
                                                        tweet_mode = 'extended',
                                                        include_retweets=True)
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'name':            item.user.name,
                    'screen_name':     item.user.screen_name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.full_text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                    'favourite_count': item.favorite_count,
                    'hashtags':        item.entities['hashtags'],
                    'status_count':    item.user.statuses_count,
                    'location':        item.place,
                    'source_device':   item.source
                }
                
                try:
                    mined['retweet_text'] = item.retweeted_status.full_text
                except:
                    mined['retweet_text'] = 'None'
                try:
                    mined['quote_text'] = item.quoted_status.full_text
                    mined['quote_screen_name'] = status.quoted_status.user.screen_name
                except:
                    mined['quote_text'] = 'None'
                    mined['quote_screen_name'] = 'None'
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %%
#Remove RETWEETS 
class TweetMiner(object):

    result_limit    =   20    
    data            =   []
    api             =   False
    
    twitter_keys = {
        'consumer_key':        'KasxVpXExYm4hVdMo0ptDcEhb',
        'consumer_secret':     'V9mCeYXPDTaPVHCscHcp3g2G53FFBCykfMzF92CTur4hRcuhjr',
        'access_token_key':    '152439706-y5Titlw7pDkXzX8ooaBRR3UQW1UnUkmSUOSwRvZU',
        'access_token_secret': '83kTOT7idOvGCA75jtqq36voUAHVEBZMRKuHRRHk9lbYA'
    }
    
    
    def __init__(self, keys_dict=twitter_keys, api=api, result_limit = 20):
        
        self.twitter_keys = keys_dict
        
        auth = tweepy.OAuthHandler(keys_dict['consumer_key'], keys_dict['consumer_secret'])
        auth.set_access_token(keys_dict['access_token_key'], keys_dict['access_token_secret'])
        
        self.api = tweepy.API(auth)
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="MMFlint", #Michael Moore 
                         mine_rewteets=False,
                         max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            if last_tweet_id:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                     count=self.result_limit,
                                                     max_id=last_tweet_id - 1,
                                                     tweet_mode = 'extended'
                                                    )        
            else:
                statuses   =   self.api.user_timeline(screen_name=user,
                                                        count=self.result_limit,
                                                        tweet_mode = 'extended')
                
            for item in statuses:

                mined = {
                    'tweet_id':        item.id,
                    'name':            item.user.name,
                    'screen_name':     item.user.screen_name,
                    'retweet_count':   item.retweet_count,
                    'text':            item.full_text,
                    'mined_at':        datetime.datetime.now(),
                    'created_at':      item.created_at,
                    'favourite_count': item.favorite_count,
                    'hashtags':        item.entities['hashtags'],
                    'status_count':    item.user.statuses_count,
                    'location':        item.place,
                    'source_device':   item.source
                }
                
                try:
                    mined['retweet_text'] = item.retweeted_status.full_text
                except:
                    mined['retweet_text'] = 'None'
                try:
                    mined['quote_text'] = item.quoted_status.full_text
                    mined['quote_screen_name'] = status.quoted_status.user.screen_name
                except:
                    mined['quote_text'] = 'None'
                    mined['quote_screen_name'] = 'None'
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %%
miner=TweetMiner(result_limit = 20 )

# %%
#Print Mined tweets as a dataframe
mined_tweets = miner.mine_user_tweets(user='MMFlint', max_pages=17)

mined_tweets_df= pd.DataFrame(mined_tweets)
# Out:
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets
# Unexpected parameter: include_retweets

# %%
#Print the 7th row to see if script is accurate 
mined_tweets_df.loc[[6]]
# Out:
#               tweet_id           name screen_name  retweet_count  \
# 6  1542208128154058758  Michael Moore     MMFlint           3623
#
#                                                 text  \
# 6  RT @RonFilipkowski: Not edited or photoshopped...
#
#                     mined_at                created_at  favourite_count  \
# 6 2022-07-06 21:02:04.121168 2022-06-29 18:07:25+00:00                0
#
#   hashtags  status_count location       source_device  \
# 6       []         16009     None  Twitter for iPhone
#
#                                         retweet_text quote_text  \
# 6  Not edited or photoshopped. https://t.co/dxSnR...       None
#
#   quote_screen_name
# 6              None

# %% [markdown]
# #### Search tweets for Biden
# https://datascienceparichay.com/article/get-data-from-twitter-api-in-python-step-by-step-guide/

# %%
#Key word search Query is not case sensitive 

search_query = "biden -filter:retweets"

# %%
# get tweets from the API
tweets = tweepy.Cursor(api.search_tweets,
              q=search_query,
              lang="en",
              since="2022-06-28").items(100)
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Total Tweets fetched: 100

# %%
# intialize the dataframe
tweets_df = pd.DataFrame()
# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name,
                                               'screen_name' : tweet.user.screen_name,
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)
# show the dataframe
tweets_df.head()
# Out:
#                                             user_name      screen_name  \
# 0  Princess Gizmo                                      GizmoGyrl
# 1  Anything U can do I can do bleeding                 star_e_dices73
# 2  Steven parker                                       Stevenp69192465
# 3  James Montgomery                                    montyhandyman17
# 4  Roger (Blocked by rudy giuliani and donald jr LOL)  TheWondersNatur
#
#      user_location  \
# 0
# 1  Los Angeles, CA
# 2  Florida, USA
# 3  Vallejo, CA
# 4  New Zealand
#
#                                                                                                                                                    user_description  \
# 0  I am Princess Gizmo. My parents tell me I am Royalty. I am a fashion Diva too.I love to run, take long walks & go shopping. My siblings are on lolcats & famous.
# 1  Anywhere but here
# 2
# 3  East bay plumber I’m not afraid of baby killers those support out of spite who hate pro life should die like there babies ripped apart
# 4  I am a hobbyist photographer and love being out and amongst Nature and just being at peace with the simple things that are around in Nature!
#
#    user_verified                      date  \
# 0  False         2022-07-07 01:10:51+00:00
# 1  False         2022-07-07 01:10:51+00:00
# 2  False         2022-07-07 01:10:51+00:00
# 3  False         2022-07-07 01:10:50+00:00
# 4  False         2022-07-07 01:10:50+00:00
#
#                                                                                                                                                                                               text  \
# 0  @Mariah2732 @robreiner All the Biden is doing
# 1  @fake_biden No he’s got a scheduling conflict - getting his ladybugs checked out
# 2  @DamianDazz @TheDemocrats The election was rigged 99% of publication was against Donald Trump 100% was for Joe Biden in his basement and look how it turned out. Joe Biden is an embarrassment!
# 3  @TJLakers01 Backwards Joe Biden
# 4  @RepStefanik Let's talk about Biden, Ukraine, and fuel prices.... https://t.co/mGV7jvrE2Q via @YouTube
#
#   hashtags              source
# 0  None     Twitter Web App
# 1  None     Twitter for iPhone
# 2  None     Twitter for iPad
# 3  None     Twitter for iPhone
# 4  None     Twitter Web App

# %%
#This function adds a new column into the dataframe above and uses a boolean value to let you know if it contains profanities    

def detect_profanity(df): 
    df['contains_profanity'] = predict(df['text'])
    return df

# %%
tweets_df_prof= detect_profanity(tweets_df)
tweets_df_prof
# Out:
#                                              user_name      screen_name  \
# 0   Princess Gizmo                                      GizmoGyrl
# 1   Anything U can do I can do bleeding                 star_e_dices73
# 2   Steven parker                                       Stevenp69192465
# 3   James Montgomery                                    montyhandyman17
# 4   Roger (Blocked by rudy giuliani and donald jr LOL)  TheWondersNatur
# ..                                                 ...              ...
# 95  James Garvey                                        Knott_again
# 96  Spot On 👍🏼                                          MissLynneO
# 97  Dilraba.                                            dilraeba
# 98  Allison Murphy                                      Allison86435394
# 99  Sunrise                                             Sunrise18673066
#
#       user_location  \
# 0
# 1   Los Angeles, CA
# 2   Florida, USA
# 3   Vallejo, CA
# 4   New Zealand
# ..          ...
# 95
# 96  Boston, MA USA
# 97
# 98  South Dakota
# 99
#
#                                                                                                                                                     user_description  \
# 0   I am Princess Gizmo. My parents tell me I am Royalty. I am a fashion Diva too.I love to run, take long walks & go shopping. My siblings are on lolcats & famous.
# 1   Anywhere but here
# 2
# 3   East bay plumber I’m not afraid of baby killers those support out of spite who hate pro life should die like there babies ripped apart
# 4   I am a hobbyist photographer and love being out and amongst Nature and just being at peace with the simple things that are around in Nature!
# ..                                                                                                                                           ...
# 95  Older, but wiser (well..maybe not). Certainly smarter then the current generation, but the future belongs to them .. God help them! .. nuf said!
# 96  Conservative Actor/SAG (we exist) 🎬 #BostonStrong 💪🏼Garden Club Lady 🪴#AmericaFirst 🤷🏼‍♀️- #Trump #BackTheBlue #God #CapeCod #AllLivesMatter
# 97  Nobility within prestige atrociously dismaying to who discerned her, whilst embedded the orb with her benevolence act as Dilraba Dilmurat. (1992)
# 98  Vote Noem out!\nChronic back pain. TOF(heart)\nNO PARTY!! BOTH LIE!  #covidisntover!! \nDidn’t vote Dem for covid to be ignored
# 99
#
#     user_verified                      date  \
# 0   False         2022-07-07 01:10:51+00:00
# 1   False         2022-07-07 01:10:51+00:00
# 2   False         2022-07-07 01:10:51+00:00
# 3   False         2022-07-07 01:10:50+00:00
# 4   False         2022-07-07 01:10:50+00:00
# ..    ...                               ...
# 95  False         2022-07-07 01:10:09+00:00
# 96  False         2022-07-07 01:10:09+00:00
# 97  False         2022-07-07 01:10:09+00:00
# 98  False         2022-07-07 01:10:09+00:00
# 99  False         2022-07-07 01:10:08+00:00
#
#                                                                                                                                                                                                                                                                                         text  \
# 0   @Mariah2732 @robreiner All the Biden is doing
# 1   @fake_biden No he’s got a scheduling conflict - getting his ladybugs checked out
# 2   @DamianDazz @TheDemocrats The election was rigged 99% of publication was against Donald Trump 100% was for Joe Biden in his basement and look how it turned out. Joe Biden is an embarrassment!
# 3   @TJLakers01 Backwards Joe Biden
# 4   @RepStefanik Let's talk about Biden, Ukraine, and fuel prices.... https://t.co/mGV7jvrE2Q via @YouTube
# ..                                                                                                     ...
# 95  @NatashaBertrand @jmhansler Because Biden has barely enough (primal) intelligence to continue breathing! Not to make light of people incarcerated in nations inimical to the USA, .. but, did they think that they immune to being used as political pawns!
# 96  @heisuke123 @andre_mihaescu Poor guy waits his whole life to get the medal and Biden effed it up 🤦‍♀️
# 97  The Highland Park shooting comes just over a week after Biden signed into law the first major federal bill passed by Congress on gun violence in decades. However, the bill would not ban the sale of assault weapons of the type used in Monday's shooting.#USA https://t.co/7pqQm7mDO2
# 98  @myrabatchelder Yes exactly both Biden and Trump failed at covid.
# 99  @POTUS #Biden tyou have done nothing but promise us so much and gave us nothing but lies. Your promised 2k a stimulus then 1k for 6 months and nothing yet. You want to look good then do an excutive order now for the monthly stimulus checks. Keep your promises
#
#    hashtags              source  contains_profanity
# 0   None     Twitter Web App     0
# 1   None     Twitter for iPhone  0
# 2   None     Twitter for iPad    0
# 3   None     Twitter for iPhone  0
# 4   None     Twitter Web App     0
# ..   ...                 ...    ..
# 95  None     Twitter for iPad    0
# 96  None     Twitter for iPhone  0
# 97  None     Twitter Web App     0
# 98  None     Twitter Web App     0
# 99  [Biden]  Twitter Web App     0
#
# [100 rows x 10 columns]

# %%
#Print only profanity tweets to see if this script works 
profanity_tweet = tweets_df_prof[tweets_df_prof['contains_profanity'] == 1]
profanity_tweet
# Out:
#             user_name    screen_name    user_location  \
# 14  Hi There Peeps🍊🍊🍊  peeps_there
# 23  Jim P.             JRPelchat      Western MA
# 64  Lesco Brandon      Skellatone     Earth
# 71  Donald Boatright   dlboatright01  Phelan, CA
# 83  nation of neal     icecoldjd1906  Los Angeles, CA
# 87  TruXeDap 🇺🇦        TruXeDap
#
#                                                                                                                                    user_description  \
# 14  I just want to make a difference.Jesus is my rock, Pro life,NRA Member.MAGA Strong ,True Patriot.
# 23  21+ Years in Nuclear Engineering, 6 + Years in Solar & Wind Projects, Engineering Trainer, and presently Power Station Ops.
# 64  IFB, MAGA, Patriot, Pure Blood, Veteran, America First! 2A, Freedom Loving, Red Blooded American! Live Free or Die! Don’t Tread On Me! 🇺🇸❤️🤍💙🇺🇸
# 71  Retired U.S. Navy
# 83  just trying to embody the note card my former boss gave me in 2012. civil rights attorney by day. sleeper at night
# 87  just an ordinary guy with an ordinary life who hates authoritarians with every fiber of his being. Fuck you Putin🖕
#
#     user_verified                      date  \
# 14  False         2022-07-07 01:10:46+00:00
# 23  False         2022-07-07 01:10:44+00:00
# 64  False         2022-07-07 01:10:25+00:00
# 71  False         2022-07-07 01:10:21+00:00
# 83  False         2022-07-07 01:10:15+00:00
# 87  False         2022-07-07 01:10:14+00:00
#
#                                                                                                                                                                                                                                                                                                                                                  text  \
# 14  @POTUS  Why is Biden selling our Reserve oil to China and Indian what the fuck is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.
# 23  Is Biden the biggest idiot ever?  No honor.  Lies out his butt.  Blames everyone else for everything. Yup, must be a Democrat. https://t.co/kDgT16S67s
# 64  Imagine if Trump had a full 8 year run of the country! I was on track to retire 5 years early! Now I’m looking at having to work another 7!\n\nFuck Joe Biden and if you voted for him (not that it mattered) Fuck you too! \n\n#fjb #fjb #fjb #fjb #fjb #fjb #fjb #fjb
# 71  @laurenboebert Congratulations. My American life sucks under this CROOKED ADMINISTRATION. \nImpeachment for Joe Biden is what America needs.
# 83  This Roe debacle has highlighted one reality. Too many on Twitter is yelling at Nancy and Biden to do something. Hard reality. We are fucked. 52 senators refuse to change senate rules.
# 87  @Stretchct @admiralmpj @ecclesias Dems don’t know how to govern or get things done? Are you fucking kidding me? Obama had to handle the worst economic crisis since the depression and he managed to pass Obamacare. Biden had to fight the worst pandemic in a century and managed to pass the infrastructure bill. SMDH https://t.co/OoxIgj7nDV
#
#    hashtags               source  contains_profanity
# 14  None     Twitter for Android  1
# 23  None     Twitter Web App      1
# 64  None     Twitter for iPhone   1
# 71  None     Twitter for Android  1
# 83  None     Twitter for iPhone   1
# 87  None     Twitter for iPad     1

# %% [markdown]
# ### Profanity Filter
#
# ##### Task - write a script that will censor words but leave tweets in tact - this will help to provide analysis later on.
#
# https://lubna2004.medium.com/profanity-to-be-or-not-to-be-dd32d53648f7

# %%
predict(['CRAP! What a stupid decision!'])

#Crap and Stupid are examples of profanities 
#This is delineated by the boolean value of one
# Out:
# array([1])

# %%
predict(['Lovely Spring Weather!'])
#There are no profanities contained in this
# Out:
# array([0])

# %%
#Use profanity Filter - to change and censor profane words

# %%
pf = ProfanityFilter()
pf.censor_char = '@'
pf.censor("Crap! What a stupid decision")
# Out:
# '@@@@! What a stupid decision'

# %%
censor_profanity_tweet = profanity_tweet

# %%
profanity_tweet['text'].dtypes
# Out:
# dtype('O')

# %%
profanity_tweet.dtypes
# Out:
# user_name             object
# screen_name           object
# user_location         object
# user_description      object
# user_verified         bool
# date                  datetime64[ns, UTC]
# text                  object
# hashtags              object
# source                object
# contains_profanity    int64
# dtype: object

# %%
#Convert text column to string
string = profanity_tweet.astype({'text':'string'})

# %%
string['text']
# Out:
# 14    @POTUS  Why is Biden selling our Reserve oil to China and Indian what the fuck is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.
# 23    Is Biden the biggest idiot ever?  No honor.  Lies out his butt.  Blames everyone else for everything. Yup, must be a Democrat. https://t.co/kDgT16S67s
# 64    Imagine if Trump had a full 8 year run of the country! I was on track to retire 5 years early! Now I’m looking at having to work another 7!
#
# Fuck Joe Biden and if you voted for him (not that it mattered) Fuck you too!
#
# #fjb #fjb #fjb #fjb #fjb #fjb #fjb #fjb
# 71    @laurenboebert Congratulations. My American life sucks under this CROOKED ADMINISTRATION.
# Impeachment for Joe Biden is what America needs.
# 83    This Roe debacle has highlighted one reality. Too many on Twitter is yelling at Nancy and Biden to do something. Hard reality. We are fucked. 52 senators refuse to change senate rules.
# 87    @Stretchct @admiralmpj @ecclesias Dems don’t know how to govern or get things done? Are you fucking kidding me? Obama had to handle the worst economic crisis since the depression and he managed to pass Obamacare. Biden had to fight the worst pandemic in a century and managed to pass the infrastructure bill. SMDH https://t.co/OoxIgj7nDV
# Name: text, dtype: string

# %%
string.dtypes
# Out:
# user_name             object
# screen_name           object
# user_location         object
# user_description      object
# user_verified         bool
# date                  datetime64[ns, UTC]
# text                  string
# hashtags              object
# source                object
# contains_profanity    int64
# dtype: object

# %%
string2 = string[["text"]]
string2.dtypes
# Out:
# text    string
# dtype: object

# %%
#This will allow us to print the entire string for the next cell
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-111-2c1c50702082>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
mystring3 = repr(string2)

pf.censor(mystring3)
# Out:
# "                                                                                                                                                                                                                                                                                                                                                 text\n14  @POTUS  Why is Biden selling our Reserve oil to China and Indian what the @@@@ is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.                                                                                                                                       \n23  Is Biden the biggest idiot ever?  No honor.  Lies out his butt.  Blames everyone else for everything. Yup, must be a Democrat. https://t.co/kDgT16S67s                                                                                                                                                                                           \n64  Imagine if Trump had a full 8 year run of the country! I was on track to retire 5 years early! Now I’m looking at having to work another 7!\n\n@@@@ Joe Biden and if you voted for him (not that it mattered) @@@@ you too! \n\n#fjb #fjb #fjb #fjb #fjb #fjb #fjb #fjb                                                                              \n71  @laurenboebert Congratulations. My American life sucks under this CROOKED ADMINISTRATION. \nImpeachment for Joe Biden is what America needs.                                                                                                                                                                                                      \n83  This Roe debacle has highlighted one reality. Too many on Twitter is yelling at Nancy and Biden to do something. Hard reality. We are @@@@@@. 52 senators refuse to change senate rules.                                                                                                                                                         \n87  @Stretchct @admiralmpj @ecclesias Dems don’t know how to govern or get things done? Are you @@@@@@@ kidding me? Obama had to handle the worst economic crisis since the depression and he managed to pass Obamacare. Biden had to fight the worst pandemic in a century and managed to pass the infrastructure bill. SMDH https://t.co/OoxIgj7nDV"

# %%
display(mystring3)
# Out:
# "                                                                                                                                                                                                                                                                                                                                                 text\n14  @POTUS  Why is Biden selling our Reserve oil to China and Indian what the fuck is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.                                                                                                                                       \n23  Is Biden the biggest idiot ever?  No honor.  Lies out his butt.  Blames everyone else for everything. Yup, must be a Democrat. https://t.co/kDgT16S67s                                                                                                                                                                                           \n64  Imagine if Trump had a full 8 year run of the country! I was on track to retire 5 years early! Now I’m looking at having to work another 7!\n\nFuck Joe Biden and if you voted for him (not that it mattered) Fuck you too! \n\n#fjb #fjb #fjb #fjb #fjb #fjb #fjb #fjb                                                                              \n71  @laurenboebert Congratulations. My American life sucks under this CROOKED ADMINISTRATION. \nImpeachment for Joe Biden is what America needs.                                                                                                                                                                                                      \n83  This Roe debacle has highlighted one reality. Too many on Twitter is yelling at Nancy and Biden to do something. Hard reality. We are fucked. 52 senators refuse to change senate rules.                                                                                                                                                         \n87  @Stretchct @admiralmpj @ecclesias Dems don’t know how to govern or get things done? Are you fucking kidding me? Obama had to handle the worst economic crisis since the depression and he managed to pass Obamacare. Biden had to fight the worst pandemic in a century and managed to pass the infrastructure bill. SMDH https://t.co/OoxIgj7nDV"

# %% [raw]
# string3 = string

# %%
def censortweet(x):
   return pf.censor(x)
string3["text"] = string3["text"].apply(censortweet)

# %%
string3
# Out:
#             user_name    screen_name    user_location  \
# 14  Hi There Peeps🍊🍊🍊  peeps_there
# 23  Jim P.             JRPelchat      Western MA
# 64  Lesco Brandon      Skellatone     Earth
# 71  Donald Boatright   dlboatright01  Phelan, CA
# 83  nation of neal     icecoldjd1906  Los Angeles, CA
# 87  TruXeDap 🇺🇦        TruXeDap
#
#                                                                                                                                    user_description  \
# 14  I just want to make a difference.Jesus is my rock, Pro life,NRA Member.MAGA Strong ,True Patriot.
# 23  21+ Years in Nuclear Engineering, 6 + Years in Solar & Wind Projects, Engineering Trainer, and presently Power Station Ops.
# 64  IFB, MAGA, Patriot, Pure Blood, Veteran, America First! 2A, Freedom Loving, Red Blooded American! Live Free or Die! Don’t Tread On Me! 🇺🇸❤️🤍💙🇺🇸
# 71  Retired U.S. Navy
# 83  just trying to embody the note card my former boss gave me in 2012. civil rights attorney by day. sleeper at night
# 87  just an ordinary guy with an ordinary life who hates authoritarians with every fiber of his being. Fuck you Putin🖕
#
#     user_verified                      date  \
# 14  False         2022-07-07 01:10:46+00:00
# 23  False         2022-07-07 01:10:44+00:00
# 64  False         2022-07-07 01:10:25+00:00
# 71  False         2022-07-07 01:10:21+00:00
# 83  False         2022-07-07 01:10:15+00:00
# 87  False         2022-07-07 01:10:14+00:00
#
#                                                                                                                                                                                                                                                                                                                                                  text  \
# 14  @POTUS  Why is Biden selling our Reserve oil to China and Indian what the @@@@ is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.
# 23  Is Biden the biggest idiot ever?  No honor.  Lies out his butt.  Blames everyone else for everything. Yup, must be a Democrat. https://t.co/kDgT16S67s
# 64  Imagine if Trump had a full 8 year run of the country! I was on track to retire 5 years early! Now I’m looking at having to work another 7!\n\n@@@@ Joe Biden and if you voted for him (not that it mattered) @@@@ you too! \n\n#fjb #fjb #fjb #fjb #fjb #fjb #fjb #fjb
# 71  @laurenboebert Congratulations. My American life sucks under this CROOKED ADMINISTRATION. \nImpeachment for Joe Biden is what America needs.
# 83  This Roe debacle has highlighted one reality. Too many on Twitter is yelling at Nancy and Biden to do something. Hard reality. We are @@@@@@. 52 senators refuse to change senate rules.
# 87  @Stretchct @admiralmpj @ecclesias Dems don’t know how to govern or get things done? Are you @@@@@@@ kidding me? Obama had to handle the worst economic crisis since the depression and he managed to pass Obamacare. Biden had to fight the worst pandemic in a century and managed to pass the infrastructure bill. SMDH https://t.co/OoxIgj7nDV
#
#    hashtags               source  contains_profanity
# 14  None     Twitter for Android  1
# 23  None     Twitter Web App      1
# 64  None     Twitter for iPhone   1
# 71  None     Twitter for Android  1
# 83  None     Twitter for iPhone   1
# 87  None     Twitter for iPad     1

# %% [markdown]
# ## Censor tweets in a dataframe

# %%
# Copy the original 
tweets_df_censor = tweets_df

# %%
# Text column to string will allow us to censor 
tweets_df_censor = tweets_df_censor.astype({'text':'string'})
tweets_df_censor.head()
# Out:
#                                             user_name      screen_name  \
# 0  Princess Gizmo                                      GizmoGyrl
# 1  Anything U can do I can do bleeding                 star_e_dices73
# 2  Steven parker                                       Stevenp69192465
# 3  James Montgomery                                    montyhandyman17
# 4  Roger (Blocked by rudy giuliani and donald jr LOL)  TheWondersNatur
#
#      user_location  \
# 0
# 1  Los Angeles, CA
# 2  Florida, USA
# 3  Vallejo, CA
# 4  New Zealand
#
#                                                                                                                                                    user_description  \
# 0  I am Princess Gizmo. My parents tell me I am Royalty. I am a fashion Diva too.I love to run, take long walks & go shopping. My siblings are on lolcats & famous.
# 1  Anywhere but here
# 2
# 3  East bay plumber I’m not afraid of baby killers those support out of spite who hate pro life should die like there babies ripped apart
# 4  I am a hobbyist photographer and love being out and amongst Nature and just being at peace with the simple things that are around in Nature!
#
#    user_verified                      date  \
# 0  False         2022-07-07 01:10:51+00:00
# 1  False         2022-07-07 01:10:51+00:00
# 2  False         2022-07-07 01:10:51+00:00
# 3  False         2022-07-07 01:10:50+00:00
# 4  False         2022-07-07 01:10:50+00:00
#
#                                                                                                                                                                                               text  \
# 0  @Mariah2732 @robreiner All the Biden is doing
# 1  @fake_biden No he’s got a scheduling conflict - getting his ladybugs checked out
# 2  @DamianDazz @TheDemocrats The election was rigged 99% of publication was against Donald Trump 100% was for Joe Biden in his basement and look how it turned out. Joe Biden is an embarrassment!
# 3  @TJLakers01 Backwards Joe Biden
# 4  @RepStefanik Let's talk about Biden, Ukraine, and fuel prices.... https://t.co/mGV7jvrE2Q via @YouTube
#
#   hashtags              source  contains_profanity
# 0  None     Twitter Web App     0
# 1  None     Twitter for iPhone  0
# 2  None     Twitter for iPad    0
# 3  None     Twitter for iPhone  0
# 4  None     Twitter Web App     0

# %%
#Run dataframe through censortweet function from above 
tweets_df_censor["text"] = tweets_df_censor["text"].apply(censortweet)

# %%
#Check that function worked - row 14 has the profanities censored using the functions
tweets_df_censor.loc[[14]]
# Out:
#             user_name  screen_name user_location  \
# 14  Hi There Peeps🍊🍊🍊  peeps_there
#
#                                                                                      user_description  \
# 14  I just want to make a difference.Jesus is my rock, Pro life,NRA Member.MAGA Strong ,True Patriot.
#
#     user_verified                      date  \
# 14  False         2022-07-07 01:10:46+00:00
#
#                                                                                                                                                                                                           text  \
# 14  @POTUS  Why is Biden selling our Reserve oil to China and Indian what the @@@@ is that he's doing it on purpose. He needs to be investigated immediately and impeached  then in prison for what he's done.
#
#    hashtags               source  contains_profanity
# 14  None     Twitter for Android  1
